# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = {
    "Hours" : [1,2,3,4,5],
    "Marks" : [10,20,30,40,50]
}

# %%
df = pd.DataFrame(data)

# %%
df.to_csv("student_data.csv", index = False)

# %%
df = pd.read_csv("student_data.csv")

# %%
df
# Out:
#    Hours  Marks
# 0      1     10
# 1      2     20
# 2      3     30
# 3      4     40
# 4      5     50

# %%
df.head(2)
# Out:
#    Hours  Marks
# 0      1     10
# 1      2     20

# %%
df.tail(3)
# Out:
#    Hours  Marks
# 2      3     30
# 3      4     40
# 4      5     50

# %%
df.columns
# Out:
# Index(['Hours', 'Marks'], dtype='object')

# %%
df.shape
# Out:
# (5, 2)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#           Hours      Marks
# count  5.000000   5.000000
# mean   3.000000  30.000000
# std    1.581139  15.811388
# min    1.000000  10.000000
# 25%    2.000000  20.000000
# 50%    3.000000  30.000000
# 75%    4.000000  40.000000
# max    5.000000  50.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   5 non-null      int64
#  1   Marks   5 non-null      int64
# dtypes: int64(2)
# memory usage: 212.0 bytes

# %%
plt.figure(figsize = (5,4))
plt.scatter(df["Hours"], df["Marks"])
plt.title("Graph")
plt.xlabel("Hours")
plt.ylabel("Marks")
plt.show()

# %%
plt.figure(figsize = (5,4))
plt.plot(df["Hours"], df["Marks"])
plt.title("Graph")
plt.xlabel("Hours")
plt.ylabel("Marks")
plt.show()

# %%
plt.figure(figsize = (5,4))
plt.bar(df["Hours"], df["Marks"])
plt.title("Graph")
plt.xlabel("Hours")
plt.ylabel("Marks")
plt.show()

# %%
plt.figure(figsize = (5,4))
plt.hist2d(df["Hours"], df["Marks"])
plt.title("Graph")
plt.xlabel("Hours")
plt.ylabel("Marks")
plt.show()

# %%
plt.figure(figsize = (5,4))
plt.hexbin(df["Hours"], df["Marks"])
plt.title("Graph")
plt.xlabel("Hours")
plt.ylabel("Marks")
plt.show()
plt.show()

# %%
df.head()
# Out:
#    Hours  Marks
# 0      1     10
# 1      2     20
# 2      3     30
# 3      4     40
# 4      5     50

# %%
from sklearn.model_selection import train_test_split
x = df[["Hours"]]
y = df["Marks"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25,random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train, y_train)
# Out:
# 1.0

# %%
lr.predict([[4]])
# Out:
# C:\Users\agraw\Downloads\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([40.])
