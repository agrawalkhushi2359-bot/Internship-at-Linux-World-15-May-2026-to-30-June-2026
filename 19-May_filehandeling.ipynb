# %%
with open("doc.txt", "w") as f:
    data = f.write("Hello Python")
    print(data)
# Out:
# 12

# %%
with open("doc.txt", "r") as f:
    data = f.read()
    print(data)
# Out:
# Hello Python

# %%
with open("doc.txt", "a") as f:
    f.write("\nI am Khushi Agrawal")

# %%
with open("doc.txt", "r") as f:
    data = f.read()
    print(data)
# Out:
# Hello Python
# I am Khushi Agrawal

# %%
with open("doc.txt","r+") as f:
    #f.write("\n Nice to meet you")
    data = f.read()
    print(data)
# Out:
#  Nice to meet you

# %%
with open("user input.txt", "w") as f:
    Name = input("Enter your name")
    Domain = input("Enter your Domain")
    f.write(Name)
# Out:
# Enter your name Khushi Agrawal
# Enter your Domain ML

# %%
with open("user input.txt","r") as f:
    print(f.read())
# Out:
# Khushi Agrawal

# %%
def create_new_password():
    new_password = input("enter your new password")
    with open("new file", "w") as nf:
        nf.write(new_password)
def create_secrete_password():
    secrete_password = input("enter your screte password")
    with open("new file","r") as nf:
        new_password = nf.read()
    if secrete_password == new_password:
        new_password = input("enter your new  secrete password")
        with open("new file", "w"):
            nf.write(new_password)
def read_secrete_password():
    secrete_password = input("enter your screte password")
    with open("new file","r") as nf:
        new_password = nf.read()
        if secrete_password == new_password:
            with open("new file", "r"):
                nf.read()
while True:
    print("""
    1.Create new password
    2.Create secrete password
    3.Read secrete password
    4.Exit
    """)
    choice = int(input("Enter your Choice"))
    if choice == 1:
        create_new_password()
    elif choice == 2:
        create_secrete_password()
    elif choice == 3:
        read_secrete_password()
    elif choice == 4:
        break
    else:
        print("enter valid choice")
# Out:
#     1.Create new password
#     2.Create secrete password
#     3.Read secrete password
#     4.Exit
# Enter your Choice 5
# enter valid choice
#
#     1.Create new password
#     2.Create secrete password
#     3.Read secrete password
#     4.Exit
