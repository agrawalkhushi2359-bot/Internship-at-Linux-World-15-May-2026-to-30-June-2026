# %%
# null values removal in dataset
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
#importing my dataset in my program in the form of dataframe
dataset = pd.read_csv(r"C:\Users\agraw\OneDrive\Desktop\loan dataset.zip")

# %%
# displaying my head rows
dataset.head()
# Out:
#     loan_id gender married dependents     education self_employed  \
# 0  lp001002   male      no          0      graduate            no
# 1  lp001003   male     yes          1      graduate            no
# 2  lp001005   male     yes          0      graduate           yes
# 3  lp001006   male     yes          0  not graduate            no
# 4  lp001008   male      no          0      graduate            no
#
#    applicantincome  coapplicantincome  loanamount  loan_amount_term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    credit_history property_area loan_status
# 0             1.0         urban           y
# 1             1.0         rural           n
# ...

# %%
# printing shape of dataset
dataset.shape
# Out:
# (614, 13)

# %%
# checking null values in dataset 
dataset.isnull()
# Out:
#      loan_id  gender  married  dependents  education  self_employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      applicantincome  coapplicantincome  loanamount  loan_amount_term  \
# 0              False              False        True             False
# ...

# %%
# displayong sum of null values column wise
dataset.isnull().sum()
# Out:
# loan_id               0
# gender               13
# married               3
# dependents           15
# education             0
# self_employed        32
# applicantincome       0
# coapplicantincome     0
# loanamount           22
# loan_amount_term     14
# credit_history       50
# property_area         0
# loan_status           0
# dtype: int64

# %%
# displaying overall null values in dataset
print(dataset.isnull().sum().sum())
# Out:
# 149

# %%
# displaying shape of rows or total number of rows
dataset.shape[0]
# Out:
# 614

# %%
#  displaying shape of columns or total number of columns
dataset.shape[1]
# Out:
# 13

# %%
# calculating percentage of null values column wise
(dataset.isnull().sum()/dataset.shape[0])*100
# Out:
# loan_id              0.000000
# gender               2.117264
# married              0.488599
# dependents           2.442997
# education            0.000000
# self_employed        5.211726
# applicantincome      0.000000
# coapplicantincome    0.000000
# loanamount           3.583062
# loan_amount_term     2.280130
# credit_history       8.143322
# property_area        0.000000
# loan_status          0.000000
# dtype: float64

# %%
# calculating null values in dataset
print((dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100)
# Out:
# 1.8667000751691305

# %%
# displaying not null or filled values in dataset
dataset.notnull()
# Out:
#      loan_id  gender  married  dependents  education  self_employed  \
# 0       True    True     True        True       True           True
# 1       True    True     True        True       True           True
# 2       True    True     True        True       True           True
# 3       True    True     True        True       True           True
# 4       True    True     True        True       True           True
# ..       ...     ...      ...         ...        ...            ...
# 609     True    True     True        True       True           True
# 610     True    True     True        True       True           True
# 611     True    True     True        True       True           True
# 612     True    True     True        True       True           True
# 613     True    True     True        True       True           True
#
#      applicantincome  coapplicantincome  loanamount  loan_amount_term  \
# 0               True               True       False              True
# ...

# %%
# displaying total number of filled values columnwise
dataset.notnull().sum()
# Out:
# loan_id              614
# gender               601
# married              611
# dependents           599
# education            614
# self_employed        582
# applicantincome      614
# coapplicantincome    614
# loanamount           592
# loan_amount_term     600
# credit_history       564
# property_area        614
# loan_status          614
# dtype: int64

# %%
# printing overall filled values in dataset
print(dataset.notnull().sum().sum())
# Out:
# 7833

# %%
# plotting heatmap 
sns.heatmap(dataset.isnull())
plt.show()

# %%
# deleting or dropping column in dataset (does not affect my real excel sheet)
dataset.drop(columns = ["credit_history"], inplace = True)

# %%
dataset.head()
# Out:
#     loan_id gender married dependents     education self_employed  \
# 0  lp001002   male      no          0      graduate            no
# 1  lp001003   male     yes          1      graduate            no
# 2  lp001005   male     yes          0      graduate           yes
# 3  lp001006   male     yes          0  not graduate            no
# 4  lp001008   male      no          0      graduate            no
#
#    applicantincome  coapplicantincome  loanamount  loan_amount_term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#   property_area loan_status
# 0         urban           y
# 1         rural           n
# 2         urban           y
# 3         urban           y
# ...

# %%
dataset.shape
# Out:
# (614, 12)

# %%
# dropping my all rows that contain null values
dataset.dropna(inplace = True)

# %%
dataset.shape
# Out:
# (523, 12)

# %%
# calculating loss in data after dropping rows and columns
((614-523)/614)*100
# Out:
# 14.82084690553746
