# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
# accessing the image, displaying in window, resizing
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
# reading the image, showing the image
cv2.imshow("kitty kat", img)
# resizing the image
res_img = cv2.resize(img, (500,500))
cv2.imshow("kitty kat", res_img)
cv2.waitKey(0)
# image frame will in time of unit miliseconds and argument 0 means after pressing anykey of keyboard window will close
#cv2.destroyWindow()
# destroy will close window
cv2.destroyAllWindows()

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
# dtype of image is array, format is RGB
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
# stacking image horizontally
res_img = cv2.resize(img, (200, 150))
h = np.hstack((res_img, res_img))
cv2.imshow("kitty kat", h)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# stacking image vertically
v = np.vstack((res_img, res_img))
cv2.imshow("kitty kat", v)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# stacking image vertically and horizantally
h = np.hstack((res_img, res_img))
v = np.vstack((h, h))
cv2.imshow("kitty kat", v)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# printing all images name in that particular folder
list_name  = os.listdir(r"C:\Users\agraw\OneDrive\Desktop\images for opencv")
list_name
# Out:
# ['20250430_153656-COLLAGE.jpg',
#  'binary image.png',
#  'IMG_20241105_075351.jpg',
#  'IMG_20260222_100947.jpg']

# %%
# slideshow of images
list_name  = os.listdir(r"C:\Users\agraw\OneDrive\Desktop\images for opencv")
for name in list_name:
    img = cv2.imread("C:\\Users\\agraw\\OneDrive\\Desktop\\images for opencv" + "\\" + name)
    res_img = cv2.resize(img, (500,500))
    cv2.imshow("kitty kat", res_img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
# converting grayscale scale from RGB
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg", 0)
res_img = cv2.resize(img, (500,500))
print(img.shape)
cv2.imshow("kitty kat", res_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (315, 250)

# %%
# converting BGR 
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg", 1)
res_img = cv2.resize(img, (500,500))
print(img.shape)
cv2.imshow("kitty kat", res_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (315, 250, 3)

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg", 1)
res_img = cv2.resize(img, (500,500))

# adding text on image
txt_img = cv2.putText(res_img, "Kitty Kat", (50,70), cv2.FONT_HERSHEY_DUPLEX, 3, (0,0,255), 3, cv2.LINE_8, False)

cv2.imshow("kitty kat", txt_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg", 1)
res_img = cv2.resize(img, (500,700))

# adding line in picture
line_img = cv2.line(res_img, (150,190), (360,170), (0,255,0), 4, 4)

cv2.imshow("kitty kat", line_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg", 1)
res_img = cv2.resize(img, (500,700))

# adding rectangle in picture
rec_img = cv2.rectangle(res_img, (100,50), (430,470), (0,255,0), 4, 16)

cv2.imshow("kitty kat", rec_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg", 1)
res_img = cv2.resize(img, (500,700))

# adding circle in picture
circle_img = cv2.circle(res_img, (270,300), 150, (0,255,0), 4, 16)

cv2.imshow("kitty kat", circle_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg", 1)
res_img = cv2.resize(img, (500,700))

# adding ellipse in picture
ellipse_img = cv2.ellipse(res_img, (270,300), (150,190), 30, 0, 360, (0,255,0), 4, 16)

cv2.imshow("kitty kat", ellipse_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg", 1)
res_img = cv2.resize(img, (500,700))

# adding polylines in picture
new_img = cv2.polylines(res_img, [np.array([[100,200], [150,100], [300,200], [300,500], [100,500]])], True, (0,255,0), 4, 16)

cv2.imshow("kitty kat", new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1 = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
img2 = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\images for opencv\binary image.png")
img1 = cv2.resize(img1, (500,500))
img2 = cv2.resize(img2, (500,500))

# adding two images with different intensities
new_img = cv2.addWeighted(img1, 0.5, img2, 0.5, 1)

cv2.imshow("weighted image", new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1 = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
img2 = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\images for opencv\binary image.png")
img1 = cv2.resize(img1, (500,500))
img2 = cv2.resize(img2, (500,500))

# subtracting two images with different intensities
new_img = cv2.subtract(img1, img2)

cv2.imshow("image", new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1 = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
img2 = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\images for opencv\binary image.png")
img1 = cv2.resize(img1, (200,200))
img2 = cv2.resize(img2, (200,200))

# bitwise or
new_img = cv2.bitwise_or(img1, img2)

h = np.hstack((img1, img2, new_img))
cv2.imshow("image", h)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# bitwise and
new_img = cv2.bitwise_and(img1, img2)

h = np.hstack((img1, img2, new_img))
cv2.imshow("image", h)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# bitwise x_or
new_img = cv2.bitwise_xor(img1, img2)

h = np.hstack((img1, img2, new_img))
cv2.imshow("image", h)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# bitwise not
new_img1 = cv2.bitwise_not(img1)
new_img2 = cv2.bitwise_not(img2)
h = np.hstack((img1, img2, new_img1, new_img2))
cv2.imshow("image", h)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
print(img.shape)
res_img = cv2.resize(img, (500,700))
print(new_img.shape)

new_img = cv2.Canny(res_img, 500, 600, apertureSize = 5, L2gradient = True)

cv2.imshow("image", img)
cv2.imshow("image", new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (315, 250, 3)
# (200, 200, 3)

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
res_img = cv2.resize(img, (500,700))
w, h = res_img.shape[0], res_img.shape[1]

# rotation of image
m = cv2.getRotationMatrix2D((w/2, h/2), 90, 1)
new_img = cv2.warpAffine(res_img, m, (h,w))

cv2.imshow("image", res_img)
cv2.imshow("image", new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
res_img = cv2.resize(img, (300,400))

# blurring image - gaussian
g = cv2.GaussianBlur(res_img, (5,5), 0)

# blurring image - medianblur
m = cv2.medianBlur(res_img, 3)

# blurring image - bilateralblur
b = cv2.bilateralFilter(res_img, 9, 100, 100)

h = np.hstack((res_img, g, m, b))
cv2.imshow("image", h)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
res_img = cv2.resize(img, (300,400))

h = np.hstack((res_img, res_img))
v = np.vstack((h,h))

# saving image to ROM
cv2.imwrite("Kitty kat.png", v)

cv2.imshow("image", v)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
res_img = cv2.resize(res_img, (300,300))

# adding border in image
img1 = cv2.copyMakeBorder(res_img, 20, 20, 20, 20, cv2.BORDER_CONSTANT, None, value = 2)
img1 = cv2.resize(img1, (300,300))

img2 = cv2.copyMakeBorder(res_img, 20, 20, 20, 20, cv2.BORDER_DEFAULT, None, value = 2)
img2 = cv2.resize(img2, (300,300))

h = np.hstack((res_img, img1, img2))
cv2.imshow("image", h)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
res_img = cv2.resize(res_img, (300,300))

m = np.ones((15,15), np.int8)

en = cv2.erode(res_img, m,  1)
di = cv2.dilate(res_img,m, 1)

cv2.imshow("img",res_img)
cv2.imshow("er",en)
cv2.imshow("di",di)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
res_img = cv2.resize(res_img, (200,300))
k = np.ones((15,15), np.int8)

new_img1 = cv2.morphologyEx(res_img, cv2.MORPH_BLACKHAT,k, 1)
new_img2 = cv2.morphologyEx(res_img, cv2.MORPH_TOPHAT,k, 1)
new_img3 = cv2.morphologyEx(res_img, cv2.MORPH_GRADIENT,k, 1)
new_img4 = cv2.morphologyEx(res_img, cv2.MORPH_OPEN,k, 1)
new_img5 = cv2.morphologyEx(res_img, cv2.MORPH_CLOSE,k, 1)

h = np.hstack((res_img, new_img1, new_img2, new_img3, new_img4, new_img5))
cv2.imshow("h",h)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# creating white window
k = np.ones((200,200), np.uint8)*255

cv2.imshow("k",k)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# creating black window
k = np.zeros((200,200), np.uint8)*255

cv2.imshow("k",k)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
res_img = cv2.resize(res_img, (200,300))

#creating pyramid of images - pyrdown
new = cv2.pyrDown(res_img)
print(new.shape)

new1 = cv2.pyrDown(new)
print(new1.shape)

new2 = cv2.pyrDown(new)
print(new2.shape)

cv2.imshow("res_img",res_img)
cv2.imshow("new",new)
cv2.imshow("new1",new1)
cv2.imshow("new2",new2)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (150, 100, 3)
# (75, 50, 3)
# (75, 50, 3)

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
res_img = cv2.resize(res_img, (50,50))

#creating pyramid of images - pyrup
new = cv2.pyrUp(res_img)
print(new.shape)

new1 = cv2.pyrUp(new)
print(new1.shape)

new2 = cv2.pyrUp(new)
print(new2.shape)

cv2.imshow("res_img",res_img)
cv2.imshow("new",new)
cv2.imshow("new1",new1)
cv2.imshow("new2",new2)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (100, 100, 3)
# (200, 200, 3)
# (200, 200, 3)

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
res_img = cv2.resize(res_img, (500,700))

m = np.float32([[10,10,100], [10,11,50]])
new = cv2.warpAffine(res_img, m, (500, 500))

cv2.imshow("res_img",res_img)
cv2.imshow("m",m)
cv2.imshow("new",new)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
res_img = cv2.resize(res_img, (500,700))

# changing colour of image
new = cv2.cvtColor(res_img, cv2.COLOR_BGR2YCrCb)

cv2.imshow("res_img",res_img)
cv2.imshow("new",new)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("Kitty kat.png")
res_img = cv2.resize(img, (300,400))
print(res_img.shape)

# cropping the image
crop = res_img[120:180, 150:300]

cv2.imshow("res_img",res_img)
cv2.imshow("crop",crop)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (400, 300, 3)

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
res_img = cv2.resize(res_img, (500,700))

#f1 = cv2.flip(res_img, 1)                            #flipping image about y-axis
#f1 = cv2.flip(res_img, 0)                            #flipping image about x-axis
#f1 = cv2.flip(res_img, -1)                           #flipping image about y- axis and x-axis both
#f1 = cv2.rotate(img,cv2.ROTATE_90_COUNTERCLOCKWISE)  # rotating image
f1 = cv2.transpose(img)                               # transposing an image

cv2.imshow("res_img",f1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")

# perspective transformation
w,h = (500, 600)
src = np.float32([[101,142], [385,142], [43,535], [496,514]])
dst = np.float32([[0,0], [w,0], [0,h], [w,h]])
m = cv2.getPerspectiveTransform(src, dst)
new_img = cv2.warpPerspective(img, m, (w,h))

cv2.imshow("new_img",new_img)
cv2.imshow("img",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
res_img = cv2.resize(img, (500,700))
res_img = cv2.cvtColor(res_img, cv2.COLOR_BGR2GRAY)

# thresholding the images
#b, th = cv2.threshold(res_img, 100, 255, cv2.THRESH_BINARY)
#b, th = cv2.threshold(res_img, 100, 255, cv2.THRESH_BINARY_INV)
b, th = cv2.threshold(res_img, 100, 255, cv2.THRESH_TRIANGLE)
print(b)

cv2.imshow("threshold",th)
cv2.imshow("img",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 71.0

# %%
blank_white = np.ones((500,500,3), np.uint8)*255
blank_black = np.zeros((500,500,3), np.uint8)*255

# histogram plotting of an image
#hist = cv2.calcHist([blank_white], [0], None, [256], [0,256])
hist = cv2.calcHist([blank_black], [0], None, [256], [0,256])

plt.figure(figsize = (5,3))
plt.plot(hist)
plt.show()

cv2.imshow("blank_white", blank_white)
cv2.imshow("blank_black", blank_black)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
res_img = cv2.resize(img, (500,700))

# histogram plotting of an image
hist = cv2.calcHist([res_img], [0], None, [256], [0,256])

plt.figure(figsize = (7,3))
plt.plot(hist)
plt.show()

cv2.imshow("res_img", res_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
res_img = cv2.resize(img, (500,700))
gry = cv2.cvtColor(res_img, cv2.COLOR_BGR2GRAY)

# equilizing an image
eq = cv2.equalizeHist(gry)

hist = cv2.calcHist([gry], [0], None, [256], [0,256])
plt.figure(figsize = (7,3))
plt.plot(hist)
plt.show()

cv2.imshow("res_img", res_img)
cv2.imshow("eq", eq)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
res_img = cv2.resize(img, (500,700))
gry = cv2.cvtColor(res_img, cv2.COLOR_BGR2GRAY)

b, th = cv2.threshold(gry, 100, 255, cv2.THRESH_BINARY)

c,h = cv2.findContours(th, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
new_img = cv2.drawContours(res_img, c, -1, (255,0,0), 2)

cv2.imshow("new_img", new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Sunday Tasks

# %%
# applying filters on image

img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
picture_rgb = cv2.resize(img, (500,700))
gray = cv2.cvtColor(picture_rgb, cv2.COLOR_RGB2GRAY)

blur = cv2.GaussianBlur(picture_rgb, (15,15), 0)

negative = cv2.bitwise_not(picture_rgb)

kernel = np.array([[-2,-1,0],[-1,1,1],[0,1,2]])

emboss = cv2.filter2D(picture_rgb, -1, kernel)

inv = 255 - gray
blur_sketch = cv2.GaussianBlur(inv, (21,21), 0)
pencil = cv2.divide(gray, 255-blur_sketch, scale=256)

bright = cv2.convertScaleAbs(picture_rgb, alpha=1, beta=50)

# Display
images = [("Original", picture_rgb),("Grayscale", gray),("Blur", blur),("Negative", negative),("Emboss", emboss),("Pencil Sketch", pencil),("Brightness", bright)]

plt.figure(figsize=(12,6))

for i, (title, picture) in enumerate(images, 1):

    plt.subplot(2,4,i)
    if len(picture.shape) == 2:
        plt.imshow(picture, cmap="gray")
    else:
        plt.imshow(picture)

    plt.title(title)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
# cropping video

cap = cv2.VideoCapture(r"C:\Users\agraw\Downloads\Telegram Desktop\Gon the stone age boy Hindi Kids super hit daily s.mp4")

while True:
    ret, frame = cap.read()
    if not ret:
        break

    crop1 = frame[0:360, 0:426]
    crop2 = frame[0:360, 426:852]
    crop3 = frame[360:720, 0:426]
    crop4 = frame[360:720, 426:852]

    # Same size
    crop1 = cv2.resize(crop1, (400,250))
    crop2 = cv2.resize(crop2, (400,250))
    crop3 = cv2.resize(crop3, (400,250))
    crop4 = cv2.resize(crop4, (400,250))

    # White gap
    gap_v = np.ones((250,20,3), dtype=np.uint8) * 255
    gap_h = np.ones((20,820,3), dtype=np.uint8) * 255

    row1 = np.hstack((crop1, gap_v, crop2))
    row2 = np.hstack((crop3, gap_v, crop4))

    final = np.vstack((row1, gap_h, row2))

    cv2.imshow("4 Cropped Video Regions", final)

    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# cropping image

img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

h, w, _ = img.shape

height = int(input("Enter Height: "))
width = int(input("Enter Width: "))

if height > h or width > w:
    print("Crop size cannot exceed image dimensions!")
    print(f"Maximum Height = {h}")
    print(f"Maximum Width = {w}")

else:
    crop = img[:height, :width]

    plt.imshow(crop)
    plt.title("Cropped Image")
    plt.axis("off")
    plt.show()
# Out:
# Enter Height:  100
# Enter Width:  50

# %%
# displaying two videos side by side

from IPython.display import clear_output

#cap1 = cv2.VideoCapture(r"C:\Users\agraw\Downloads\Telegram Desktop\Gon the stone age boy Hindi Kids super hit daily s.mp4")
#cap2 = cv2.VideoCapture(r"C:\Users\agraw\Downloads\Telegram Desktop\Gon the stone age boy Hindi Kids super hit daily s.mp4")

while True:

    ret1, frame1 = cap1.read()
    ret2, frame2 = cap2.read()

    if not ret1 or not ret2:
        break

    frame1 = cv2.resize(frame1, (400,300))
    frame2 = cv2.resize(frame2, (400,300))

    frame1 = cv2.cvtColor(frame1, cv2.COLOR_BGR2RGB)
    frame2 = cv2.cvtColor(frame2, cv2.COLOR_BGR2RGB)

    gap = np.ones((300, 20, 3), dtype=np.uint8) * 255
    
    final = np.hstack((frame1,gap, frame2))

    clear_output(wait=True)

    plt.figure(figsize=(10,5))
    plt.imshow(final)
    plt.title("Video 1                                                         Video 2")
    plt.axis("off")
    plt.show()

cap1.release()
cap2.release()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 10
#       5 #cap1 = cv2.VideoCapture(r"C:\Users\agraw\Downloads\Telegram Desktop\Gon the stone age boy Hindi Kids super hit daily s.mp4")
#       6 #cap2 = cv2.VideoCapture(r"C:\Users\agraw\Downloads\Telegram Desktop\Gon the stone age boy Hindi Kids super hit daily s.mp4")
#       8 while True:
# ---> 10     ret1, frame1 = cap1.read()
#      11     ret2, frame2 = cap2.read()
#      13     if not ret1 or not ret2:
#
# NameError: name 'cap1' is not defined
