# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r"C:\Users\agraw\OneDrive\Desktop\niftyfifty.zip")
df.head()
# Out:
#    Unnamed: 0         Date   Price    Open    High     Low  Volume  %Chg
# 0           0  11-Dec-1995  877.41  882.58  882.58  874.37     0.0 -1.09
# 1           1  18-Dec-1995  882.63  883.29  883.58  881.17     0.0 -0.09
# 2           2  14-Dec-1995  884.34  890.81  891.98  884.31     0.0 -0.55
# 3           3  29-Nov-1995  845.12  845.36  845.36  822.54     0.0  0.17
# 4           4  19-Dec-1995  883.72  882.35  884.19  879.54     0.0  0.12

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Date          0
# Price         0
# Open          0
# High          0
# Low           0
# Volume        0
# %Chg          0
# dtype: int64

# %%
df.describe()
# Out:
#         Unnamed: 0        Price         Open         High          Low  \
# count  4999.000000  4999.000000  4999.000000  4999.000000  4999.000000
# mean   2499.000000  3306.953585  3307.740212  3335.757526  3277.187259
# std    1443.231328  2319.250574  2321.097771  2333.376552  2304.771313
# min       0.000000   788.150000   786.370000   805.820000   775.430000
# 25%    1249.500000  1129.935000  1131.300000  1141.925000  1120.650000
# 50%    2499.000000  2566.850000  2558.500000  2585.600000  2526.200000
# 75%    3748.500000  5262.650000  5266.425000  5302.700000  5225.625000
# max    4998.000000  8996.250000  9109.150000  9119.200000  8925.550000
#
#             Volume         %Chg
# count  4999.000000  4999.000000
# mean    104.268726     0.053735
# std      78.143533     1.585128
# min       0.000000   -12.240000
# 25%      44.960000    -0.750000
# 50%      86.440000     0.080000
# 75%     146.980000     0.880000
# max     686.890000    17.740000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4999 non-null   int64
#  1   Date        4999 non-null   object
#  2   Price       4999 non-null   float64
#  3   Open        4999 non-null   float64
#  4   High        4999 non-null   float64
#  5   Low         4999 non-null   float64
#  6   Volume      4999 non-null   float64
#  7   %Chg        4999 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 312.6+ KB

# %%
df.shape
# Out:
# (4999, 8)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Price', 'Open', 'High', 'Low', 'Volume', '%Chg'], dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0         Date   Price    Open    High     Low  Volume  %Chg
# 0           0  11-Dec-1995  877.41  882.58  882.58  874.37     0.0 -1.09
# 1           1  18-Dec-1995  882.63  883.29  883.58  881.17     0.0 -0.09
# 2           2  14-Dec-1995  884.34  890.81  891.98  884.31     0.0 -0.55
# 3           3  29-Nov-1995  845.12  845.36  845.36  822.54     0.0  0.17
# 4           4  19-Dec-1995  883.72  882.35  884.19  879.54     0.0  0.12

# %%
df.drop(columns = "Unnamed: 0", inplace = True)

# %%
df.info
# Out:
# <bound method DataFrame.info of              Date    Price     Open     High      Low  Volume  %Chg
# 0     11-Dec-1995   877.41   882.58   882.58   874.37    0.00 -1.09
# 1     18-Dec-1995   882.63   883.29   883.58   881.17    0.00 -0.09
# 2     14-Dec-1995   884.34   890.81   891.98   884.31    0.00 -0.55
# 3     29-Nov-1995   845.12   845.36   845.36   822.54    0.00  0.17
# 4     19-Dec-1995   883.72   882.35   884.19   879.54    0.00  0.12
# ...           ...      ...      ...      ...      ...     ...   ...
# 4994  16-Jun-2015  8047.30  8004.20  8061.85  7952.35  127.81  0.42
# 4995  07-Oct-2015  8177.40  8146.20  8188.90  8132.90  199.91  0.30
# 4996  17-Jun-2015  8091.55  8084.20  8136.85  8048.95  157.21  0.55
# 4997  05-Jun-2015  8114.70  8119.15  8191.00  8100.15  167.05 -0.20
# 4998  30-Sep-2015  7948.90  7924.25  7957.70  7874.50  217.19  1.35
#
# [4999 rows x 7 columns]>

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df["Day"] = df["Date"].dt.day

# %%
df["Month"] = df["Date"].dt.month

# %%
df["Year"] = df["Date"].dt.year

# %%
df.drop(columns = "Date", inplace = True)

# %%
plt.figure(figsize = (10, 5))
sns.heatmap(df.corr(), annot = True)
plt.show()

# %%
sns.pairplot(data = df)
plt.show()

# %%
df.info
# Out:
# <bound method DataFrame.info of         Price     Open     High      Low  Volume  %Chg  Day  Month  Year
# 0      877.41   882.58   882.58   874.37    0.00 -1.09   11     12  1995
# 1      882.63   883.29   883.58   881.17    0.00 -0.09   18     12  1995
# 2      884.34   890.81   891.98   884.31    0.00 -0.55   14     12  1995
# 3      845.12   845.36   845.36   822.54    0.00  0.17   29     11  1995
# 4      883.72   882.35   884.19   879.54    0.00  0.12   19     12  1995
# ...       ...      ...      ...      ...     ...   ...  ...    ...   ...
# 4994  8047.30  8004.20  8061.85  7952.35  127.81  0.42   16      6  2015
# 4995  8177.40  8146.20  8188.90  8132.90  199.91  0.30    7     10  2015
# 4996  8091.55  8084.20  8136.85  8048.95  157.21  0.55   17      6  2015
# 4997  8114.70  8119.15  8191.00  8100.15  167.05 -0.20    5      6  2015
# 4998  7948.90  7924.25  7957.70  7874.50  217.19  1.35   30      9  2015
#
# [4999 rows x 9 columns]>

# %%
df.describe()
# Out:
#              Price         Open         High          Low       Volume  \
# count  4999.000000  4999.000000  4999.000000  4999.000000  4999.000000
# mean   3306.953585  3307.740212  3335.757526  3277.187259   104.268726
# std    2319.250574  2321.097771  2333.376552  2304.771313    78.143533
# min     788.150000   786.370000   805.820000   775.430000     0.000000
# 25%    1129.935000  1131.300000  1141.925000  1120.650000    44.960000
# 50%    2566.850000  2558.500000  2585.600000  2526.200000    86.440000
# 75%    5262.650000  5266.425000  5302.700000  5225.625000   146.980000
# max    8996.250000  9109.150000  9119.200000  8925.550000   686.890000
#
#               %Chg          Day        Month        Year
# count  4999.000000  4999.000000  4999.000000  4999.00000
# mean      0.053735    15.778356     6.525505  2005.35067
# std       1.585128     8.764041     3.440354     5.78296
# min     -12.240000     1.000000     1.000000  1995.00000
# ...

# %%
sns.boxplot(x = "Price", data = df )
plt.show()

# %%
sns.boxplot(x = "Open", data = df )
plt.show()

# %%
sns.boxplot(x = "High", data = df )
plt.show()

# %%
sns.boxplot(x = "Low", data = df )
plt.show()

# %%
sns.boxplot(x = "%Chg", data = df )
plt.show()

# %%
sns.histplot(df["Price"], kde = True)
plt.show()

# %%
x = df[[ 'Open', 'High', 'Low', 'Volume', '%Chg', 'Day', 'Month',
       'Year']]
y = df["Price"]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sr = StandardScaler()
X_train = sr.fit_transform(x_train)
X_test = sr.fit_transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
lr.score(X_train, y_train)
# Out:
# 0.9999432024003362

# %%
from sklearn.metrics import r2_score
r2_score(y_test, lr.predict(X_test))
# Out:
# 0.9989547984394573
