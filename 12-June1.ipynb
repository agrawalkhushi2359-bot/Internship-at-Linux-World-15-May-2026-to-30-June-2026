# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
image_rgb = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

# %%
plt.imshow(image)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(249.5), np.float64(314.5), np.float64(-0.5))

# %%
image.dtype
# Out:
# dtype('uint8')

# %%
image.size
# Out:
# 236250

# %%
height, width, channel = image.shape
print(height, width, channel)
# Out:
# 315 250 3

# %%
import numpy as np
black_image = np.zeros((315, 250,3), dtype = np.uint8)

# %%
plt.imshow(black_image)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(249.5), np.float64(314.5), np.float64(-0.5))

# %%
white_image = np.ones((315, 250,3), dtype = np.uint8)
plt.imshow(white_image)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(249.5), np.float64(314.5), np.float64(-0.5))

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %%
copy_image = image.copy()

# %%
copy_image[:] = (0, 255, 0)   # BGR format => Green

plt.imshow(copy_image)

# %%
plt.imshow(image)
#k = cv2.cvtColor(image, cv2.COLOR_BGR2BGR555)
#plt.imshow(k)

# %%
image = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
image_rgb = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

# %%
resized_image = cv2.resize(image,(250, 150) )
resized_rgb = cv2.cvtColor(resized_image, cv2.COLOR_RGB2BGR)

# %%
plt.imshow(resized_image)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(249.5), np.float64(149.5), np.float64(-0.5))

# %%
plt.imshow(resized_rgb)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(249.5), np.float64(149.5), np.float64(-0.5))

# %%
image = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
image_1  = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
image_2 = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
fig, axes = plt.subplots(1,2)


axes[0].imshow(image_1)
axes[0].axis("off")
axes[1].imshow(resized_rgb)
axes[1].axis("off")
plt.show()

# %% [markdown]
# # cropping image

# %%
image = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
image_rgb = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

# %%
height, width, channel = image.shape
print(height, width, channel)
# Out:
# 315 250 3

# %%
start_row, end_row = 52, 200
start_column, end_column = 100, 200

# %%
cropped = image_rgb[start_row:end_row,start_column:end_column]
fig, axes = plt.subplots(1,2, figsize=(10,4))
axes[0].imshow(image_rgb)
axes[0].axis("off")
axes[1].imshow(cropped)
axes[1].axis("off")
# Out:
# (np.float64(-0.5), np.float64(99.5), np.float64(147.5), np.float64(-0.5))

# %% [markdown]
# # rotating image

# %%
image = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
image  = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

# %%
height, width = image.shape[:2]

# %%
center = (width//2, height//2)
rotation_matrix = cv2.getRotationMatrix2D(center, 45,1)
rotated = cv2.warpAffine(image, rotation_matrix, (width, height))
rotated_rgb = cv2.cvtColor(rotated, cv2.COLOR_BGR2RGB)

# %%
fig, axes = plt.subplots(1,2, figsize=(10,4))
axes[0].imshow(image_rgb)
axes[0].axis("off")
axes[1].imshow(rotated_rgb)
axes[1].axis("off")
# Out:
# (np.float64(-0.5), np.float64(249.5), np.float64(314.5), np.float64(-0.5))

# %% [markdown]
# # grayscale

# %%
image = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\OIP.jpeg")
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# %%
hsv = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)

# %%
binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
fig, axes = plt.subplots(1, 4, figsize = (10, 4))
axes[0].imshow(image_rgb)
axes[0].axis("off")
axes[1].imshow(gray, cmap = "gray")
axes[1].axis("off")
# Out:
# (np.float64(-0.5), np.float64(249.5), np.float64(314.5), np.float64(-0.5))

# %% [markdown]
# # imageprocessing

# %%
canvas = np.ones((400, 600,3), dtype=np.uint8)*255

# %%
cv2.line(canvas, (50, 50), (400, 400), (255, 0, 0))
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
cv2.line(canvas, (50, 100), (550,300), (0, 0, 255))
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.imshow(canvas)

# %%
rec = cv2.rectangle(image,(5,5),(10,7), (2))
plt.imshow(rec)

# %%
rec = cv2.circle(image, (100,100),10, (10) )
plt.imshow(rec)

# %% [markdown]
# # India's Map

# %%
img = cv2.imread(r"C:\Users\agraw\OneDrive\Desktop\India's Map.jpeg")

# %%
cv2.circle(img, (500, 300), 10, (0, 0, 255), -1)
# Out:
# array([[[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        ...,
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
# ...

# %%
cv2.putText(img, "Delhi", (510, 295), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)
# Out:
# array([[[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        ...,
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
# ...

# %%
plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(249.5), np.float64(249.5), np.float64(-0.5))
