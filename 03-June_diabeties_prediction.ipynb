# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv(r"C:\Users\agraw\OneDrive\Desktop\diabaties dataset.zip")
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df.drop(df.duplicated().sum(), inplace = True)

# %%
df["gender"].unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
sns.countplot(x = "gender", hue = "diabetes", data = df)
plt.show()

# %%
print(df["gender"].isnull().sum())
# Out:
# 0

# %%
df["gender"] = df["gender"].map({"Male" : "0", "Female" : "1", "Other" : "2"})
df["gender"] = df["gender"].astype("int64")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99999 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               99999 non-null  int64
#  1   age                  99999 non-null  float64
#  2   hypertension         99999 non-null  int64
#  3   heart_disease        99999 non-null  int64
#  4   smoking_history      99999 non-null  object
#  5   bmi                  99999 non-null  float64
#  6   HbA1c_level          99999 non-null  float64
#  7   blood_glucose_level  99999 non-null  int64
#  8   diabetes             99999 non-null  int64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 7.6+ MB

# %%
sns.countplot(x = "smoking_history", hue = "diabetes", data = df)
plt.show()

# %%
df["smoking_history"].value_counts()
# Out:
# smoking_history
# No Info        35816
# never          35094
# former          9352
# current         9286
# not current     6447
# ever            4004
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["smoking_history"] = le.fit_transform(df["smoking_history"])
df.head()
# Out:
#    gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0       1  80.0             0              1                4  25.19
# 1       1  54.0             0              0                0  27.32
# 2       0  28.0             0              0                4  27.32
# 3       1  36.0             0              0                1  23.45
# 4       0  76.0             1              1                1  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
sns.countplot(x = "age", hue = "diabetes", data = df)
plt.show()

# %%
sns.countplot(x = "hypertension", hue = "diabetes", data = df)
plt.show()

# %%
df.describe()
# Out:
#              gender           age  hypertension  heart_disease  \
# count  99999.000000  99999.000000  99999.000000   99999.000000
# mean       0.585876     41.885665      0.074841       0.039420
# std        0.492938     22.516871      0.263136       0.194594
# min        0.000000      0.080000      0.000000       0.000000
# 25%        0.000000     24.000000      0.000000       0.000000
# 50%        1.000000     43.000000      0.000000       0.000000
# 75%        1.000000     60.000000      0.000000       0.000000
# max        2.000000     80.000000      1.000000       1.000000
#
#        smoking_history           bmi   HbA1c_level  blood_glucose_level  \
# count     99999.000000  99999.000000  99999.000000         99999.000000
# mean          2.179632     27.320651      5.527502           138.057041
# std           1.889660      6.636715      1.070676            40.707063
# min           0.000000     10.010000      3.500000            80.000000
# 25%           0.000000     23.630000      4.800000           100.000000
# 50%           3.000000     27.320000      5.800000           140.000000
# 75%           4.000000     29.580000      6.200000           159.000000
# max           5.000000     95.690000      9.000000           300.000000
#
#            diabetes
# count  99999.000000
# mean       0.084991
# std        0.278869
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
sns.countplot(x = "heart_disease", hue = "diabetes", data = df)
plt.show()
df.head()
# Out:
#    gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0       1  80.0             0              1                4  25.19
# 1       1  54.0             0              0                0  27.32
# 2       0  28.0             0              0                4  27.32
# 3       1  36.0             0              0                1  23.45
# 4       0  76.0             1              1                1  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
sns.countplot(x = "bmi", hue = "diabetes", data = df)
plt.show()

# %%
df.drop(columns = "bmi", inplace = True)
df.head()
# Out:
#    gender   age  hypertension  heart_disease  smoking_history  HbA1c_level  \
# 0       1  80.0             0              1                4          6.6
# 1       1  54.0             0              0                0          6.6
# 2       0  28.0             0              0                4          5.7
# 3       1  36.0             0              0                1          5.0
# 4       0  76.0             1              1                1          4.8
#
#    blood_glucose_level  diabetes
# 0                  140         0
# 1                   80         0
# 2                  158         0
# 3                  155         0
# 4                  155         0

# %%
sns.countplot(x = "HbA1c_level", hue = "diabetes", data = df)
plt.show()

# %%
sns.countplot(x = "blood_glucose_level", hue = "diabetes", data = df)
plt.show()

# %%
df["smoking_history"].value_counts().plot(kind = "bar")
plt.show()

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease  smoking_history  HbA1c_level  \
# 0       1  80.0             0              1                4          6.6
# 1       1  54.0             0              0                0          6.6
# 2       0  28.0             0              0                4          5.7
# 3       1  36.0             0              0                1          5.0
# 4       0  76.0             1              1                1          4.8
#
#    blood_glucose_level  diabetes
# 0                  140         0
# 1                   80         0
# 2                  158         0
# 3                  155         0
# 4                  155         0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99999 entries, 0 to 99999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               99999 non-null  int64
#  1   age                  99999 non-null  float64
#  2   hypertension         99999 non-null  int64
#  3   heart_disease        99999 non-null  int64
#  4   smoking_history      99999 non-null  int64
#  5   HbA1c_level          99999 non-null  float64
#  6   blood_glucose_level  99999 non-null  int64
#  7   diabetes             99999 non-null  int64
# dtypes: float64(2), int64(6)
# memory usage: 6.9 MB

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df["gender"].describe()
# Out:
# count    99999.000000
# mean         0.585876
# std          0.492938
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          2.000000
# Name: gender, dtype: float64

# %%
df["gender"].unique()
# Out:
# array([1, 0, 2])

# %%
df["gender"] = df["gender"].fillna(df["gender"].mode)

# %%
df["gender"].unique()
# Out:
# array([1, 0, 2])

# %%
df["gender"].value_counts()
# Out:
# gender
# 1    58551
# 0    41430
# 2       18
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease  smoking_history  HbA1c_level  \
# 0       1  80.0             0              1                4          6.6
# 1       1  54.0             0              0                0          6.6
# 2       0  28.0             0              0                4          5.7
# 3       1  36.0             0              0                1          5.0
# 4       0  76.0             1              1                1          4.8
#
#    blood_glucose_level  diabetes
# 0                  140         0
# 1                   80         0
# 2                  158         0
# 3                  155         0
# 4                  155         0

# %%
from sklearn.model_selection import train_test_split
x = df.iloc[:,:-1]
y = df.iloc[:, -1]
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.20, random_state= 42)

# %%
X_train.dtypes
# Out:
# gender                   int64
# age                    float64
# hypertension             int64
# heart_disease            int64
# smoking_history          int64
# HbA1c_level            float64
# blood_glucose_level      int64
# dtype: object

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease  smoking_history  HbA1c_level  \
# 0       1  80.0             0              1                4          6.6
# 1       1  54.0             0              0                0          6.6
# 2       0  28.0             0              0                4          5.7
# 3       1  36.0             0              0                1          5.0
# 4       0  76.0             1              1                1          4.8
#
#    blood_glucose_level  diabetes
# 0                  140         0
# 1                   80         0
# 2                  158         0
# 3                  155         0
# 4                  155         0

# %%
lr.predict([[1, 80.0, 0, 1, 4, 6.6, 140]])
# Out:
# C:\Users\agraw\Downloads\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
lr.score(X_train, Y_train)*100, lr.score(X_test, Y_test)*100
# Out:
# (95.89869873373416, 95.66)

# %%
df["diabetes"].value_counts().plot(kind = "bar")
plt.show()

# %%
df["gender"].value_counts().plot(kind = "bar")
plt.show()

# %%
pd.crosstab(df["gender"], df["diabetes"])
# Out:
# diabetes      0     1
# gender
# 0         37391  4039
# 1         54091  4460
# 2            18     0

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease  smoking_history  HbA1c_level  \
# 0       1  80.0             0              1                4          6.6
# 1       1  54.0             0              0                0          6.6
# 2       0  28.0             0              0                4          5.7
# 3       1  36.0             0              0                1          5.0
# 4       0  76.0             1              1                1          4.8
#
#    blood_glucose_level  diabetes
# 0                  140         0
# 1                   80         0
# 2                  158         0
# 3                  155         0
# 4                  155         0

# %%
df.corr()
# Out:
#                        gender       age  hypertension  heart_disease  \
# gender               1.000000  0.030055     -0.014548      -0.077931
# age                  0.030055  1.000000      0.251158       0.233357
# hypertension        -0.014548  0.251158      1.000000       0.121276
# heart_disease       -0.077931  0.233357      0.121276       1.000000
# smoking_history      0.078402  0.228602      0.093149       0.027600
# HbA1c_level         -0.020090  0.101350      0.080928       0.067590
# blood_glucose_level -0.017187  0.110655      0.084349       0.070073
# diabetes            -0.037782  0.257995      0.197731       0.171743
#
#                      smoking_history  HbA1c_level  blood_glucose_level  \
# gender                      0.078402    -0.020090            -0.017187
# age                         0.228602     0.101350             0.110655
# hypertension                0.093149     0.080928             0.084349
# heart_disease               0.027600     0.067590             0.070073
# smoking_history             1.000000     0.037365             0.040197
# HbA1c_level                 0.037365     1.000000             0.166727
# blood_glucose_level         0.040197     0.166727             1.000000
# diabetes                    0.094264     0.400668             0.419512
#
#                      diabetes
# gender              -0.037782
# age                  0.257995
# hypertension         0.197731
# heart_disease        0.171743
# smoking_history      0.094264
# HbA1c_level          0.400668
# blood_glucose_level  0.419512
# diabetes             1.000000

# %%
d = df.select_dtypes(include = ["int64", "float64"])
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99999 entries, 0 to 99999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               99999 non-null  int64
#  1   age                  99999 non-null  float64
#  2   hypertension         99999 non-null  int64
#  3   heart_disease        99999 non-null  int64
#  4   smoking_history      99999 non-null  int64
#  5   HbA1c_level          99999 non-null  float64
#  6   blood_glucose_level  99999 non-null  int64
#  7   diabetes             99999 non-null  int64
# dtypes: float64(2), int64(6)
# memory usage: 6.9 MB

# %%
df.duplicated().sum()
# Out:
# np.int64(33001)

# %%
lr.score(X_train, Y_train)*100, lr.score(X_test, Y_test)*100
# Out:
# (95.89869873373416, 95.66)

# %%
y_pred = lr.predict(x_test)
sns.countplot(x = y_train, hue = y_pred, data = df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 y_pred = lr.predict(x_test)
#       2 sns.countplot(x = y_train, hue = y_pred, data = df)
#       3 plt.show()
#
# NameError: name 'x_test' is not defined
