# %%
import os
os.chdir(r"C:\Users\agraw\OneDrive\Documents")
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.linear_model  import LinearRegression  
df = pd.read_csv("Student_Performance.csv")

# %%
print(df.isnull().sum())
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores  Sleep Hours  \
# count    9873.000000      9873.000000  9873.000000
# mean        4.992100        69.441102     6.531652
# std         2.589081        17.325601     1.697683
# min         1.000000        40.000000     4.000000
# 25%         3.000000        54.000000     5.000000
# 50%         5.000000        69.000000     7.000000
# 75%         7.000000        85.000000     8.000000
# max         9.000000        99.000000     9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                       9873.000000        9873.000000
# mean                           4.583004          55.216651
# std                            2.867202          19.208570
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          70.000000
# ...

# %%
plt.scatter(df["Hours Studied"], df["Performance Index"])
plt.title("Hours Studied vs Performance Index")
plt.xlabel("Hours Studied")
plt.ylabel("Performance Index")
plt.show()
plt.savefig("graph1.jpeg")

# %%
plt.scatter( df["Sleep Hours"], df["Performance Index"])
plt.title("Sleep Hours vs Performance Index")
plt.ylabel("Performance Index")
plt.xlabel("Sleep Hours")
plt.show()
plt.savefig("graph1.jpeg")

# %%
plt.scatter( df["Previous Scores"], df["Performance Index"])
plt.title("Previous Scores vs Performance Index")
plt.ylabel("Performance Index")
plt.xlabel("Previous Scores")
plt.show()
plt.savefig("graph1.jpeg")

# %%
plt.scatter( df["Sample Question Papers Practiced"], df["Performance Index"])
plt.title("Sample Question Papers Practiced vs Performance Index")
plt.ylabel("Performance Index")
plt.xlabel("Sample Question Papers Practiced")
plt.show()
plt.savefig("graph1.jpeg")

# %%
plt.scatter( df["Extracurricular Activities"], df["Performance Index"])
plt.title("Extracurricular Activities vs Performance Index")
plt.ylabel("Performance Index")
plt.xlabel("Extracurricular Activities")
plt.show()
plt.savefig("graph1.jpeg")

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
#y = mx+c , where y = Performance Index
model = LinearRegression()
x = df[["Previous Scores","Sleep Hours", "Sample Question Papers Practiced", "Hours Studied"]]
y =  df["Performance Index"]
model.fit(x.values,y)
print(model.predict([[81,5,8,5]]))
# Out:
# [66.95052778]

# %%
y_pred = model.predict(x)
print(y_pred)
# Out:
# [91.52595434 63.46741922 44.73520359 ... 72.68243117 94.04832183
#  65.58773847]
# C:\Users\agraw\Downloads\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2684: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
